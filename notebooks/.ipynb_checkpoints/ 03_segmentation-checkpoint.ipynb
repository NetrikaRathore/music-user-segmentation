# %%
# Cell 1 — Imports and load features
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid')

user_features = pd.read_csv('../data/processed/user_features.csv')
print(f"Loaded: {user_features.shape}")
# Out:
# Loaded: (962037, 19)

# %%
# Cell 2 — Select features for clustering
# Drop non-numeric / identifier columns
cluster_cols = [
    'total_plays', 'unique_tracks', 'unique_artists',
    'repeat_rate', 'artist_loyalty', 'genre_diversity',
    'avg_danceability', 'avg_energy', 'avg_valence',
    'avg_acousticness', 'avg_instrumentalness',
    'avg_tempo', 'avg_loudness', 'avg_track_year'
]

X = user_features[cluster_cols].copy()

# Scale features — essential for KMeans
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(f"Feature matrix: {X_scaled.shape}")
# Out:
# Feature matrix: (962037, 14)

# %%
# Cell 3 — Find best number of clusters (elbow + silhouette)
inertia    = []
silhouette = []
k_range    = range(2, 9)

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X_scaled)
    inertia.append(km.inertia_)
    silhouette.append(silhouette_score(X_scaled, km.labels_))
    print(f"k={k}  inertia={km.inertia_:.0f}  silhouette={silhouette[-1]:.3f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(k_range, inertia, 'o-', color='steelblue')
axes[0].set_title('Elbow method — pick where curve bends')
axes[0].set_xlabel('Number of clusters (k)')
axes[0].set_ylabel('Inertia')

axes[1].plot(k_range, silhouette, 'o-', color='coral')
axes[1].set_title('Silhouette score — higher is better')
axes[1].set_xlabel('Number of clusters (k)')
axes[1].set_ylabel('Silhouette score')

plt.tight_layout()
plt.savefig('../data/processed/plot_cluster_selection.png', dpi=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 10
#       6 for k in k_range:
#       7     km = KMeans(n_clusters=k, random_state=42, n_init=10)
#       8     km.fit(X_scaled)
#       9     inertia.append(km.inertia_)
# ---> 10     silhouette.append(silhouette_score(X_scaled, km.labels_))
#      11     print(f"k={k}  inertia={km.inertia_:.0f}  silhouette={silhouette[-1]:.3f}")
#      12
#      13 fig, axes = plt.subplots(1, 2, figsize=(12, 4))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\cluster\_unsupervised.py:146, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     144     else:
#     145         X, labels = X[indices], labels[indices]
# --> 146 return float(np.mean(silhouette_samples(X, labels, metric=metric, **kwds)))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\cluster\_unsupervised.py:310, in silhouette_samples(X, labels, metric, **kwds)
#     306 kwds["metric"] = metric
#     307 reduce_func = functools.partial(
#     308     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     309 )
# --> 310 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     311 intra_clust_dists, inter_clust_dists = results
#     312 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:2264, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2262 else:
#    2263     X_chunk = X[sl]
# -> 2264 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2265 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2266     metric, None
#    2267 ) is euclidean_distances:
#    2268     # zeroing diagonal, taking care of aliases of "euclidean",
#    2269     # i.e. "l2"
#    2270     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:2473, in pairwise_distances(X, Y, metric, n_jobs, ensure_all_finite, **kwds)
#    2470         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2471     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2473 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:1969, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1966     Y = X
#    1968 if effective_n_jobs(n_jobs) == 1:
# -> 1969     return func(X, Y, **kwds)
#    1971 # enforce a threading backend to prevent data communication overhead
#    1972 fd = delayed(_transposed_dist_wrapper)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:371, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     365     if Y_norm_squared.shape != (1, Y.shape[0]):
#     366         raise ValueError(
#     367             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     368             f"Y_norm_squared of shape {original_shape}."
#     369         )
# --> 371 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\metrics\pairwise.py:407, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     404     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     405 else:
#     406     # if dtype is already float64, no need to chunk and upcast
# --> 407     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     408     distances += XX
#     409     distances += YY
#
# MemoryError: Unable to allocate 1020. MiB for an array with shape (139, 962037) and data type float64

# %%
from sklearn.metrics import silhouette_score
import numpy as np

inertia    = []
silhouette = []
k_range    = range(2, 9)

# sample 5000 users for silhouette — enough to be accurate, small enough for RAM
SAMPLE_SIZE = 5000
np.random.seed(42)
sample_idx = np.random.choice(len(X_scaled), size=SAMPLE_SIZE, replace=False)
X_sample   = X_scaled[sample_idx]

for k in k_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X_scaled)                          # fit on ALL data
    inertia.append(km.inertia_)

    sample_labels = km.labels_[sample_idx]    # silhouette on sample only
    sil = silhouette_score(X_sample, sample_labels)
    silhouette.append(sil)
    print(f"k={k}  inertia={km.inertia_:.0f}  silhouette={sil:.3f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(k_range, inertia, 'o-', color='steelblue')
axes[0].set_title('Elbow method — pick where curve bends')
axes[0].set_xlabel('Number of clusters (k)')
axes[0].set_ylabel('Inertia')

axes[1].plot(k_range, silhouette, 'o-', color='coral')
axes[1].set_title('Silhouette score — higher is better')
axes[1].set_xlabel('Number of clusters (k)')
axes[1].set_ylabel('Silhouette score')

plt.tight_layout()
plt.savefig('../data/processed/plot_cluster_selection.png', dpi=120)
plt.show()
# Out:
# k=2  inertia=11525922  silhouette=0.219
# k=3  inertia=10041474  silhouette=0.187
# k=4  inertia=9272912  silhouette=0.135
# k=5  inertia=8590502  silhouette=0.128
# k=6  inertia=8174380  silhouette=0.133
# k=7  inertia=7816331  silhouette=0.116
# k=8  inertia=7475314  silhouette=0.121

# %%
# Cell 4 — Fit final KMeans (adjust k based on cell 3 output)
BEST_K = 4   # change this based on elbow/silhouette plots

km_final = KMeans(n_clusters=BEST_K, random_state=42, n_init=10)
user_features['cluster'] = km_final.fit_predict(X_scaled)

print(f"Cluster distribution:")
print(user_features['cluster'].value_counts().sort_index())
# Out:
# Cluster distribution:
# cluster
# 0    171422
# 1    248907
# 2    408553
# 3    133155
# Name: count, dtype: int64

# %%
# Cell 5 — Visualise clusters in 2D using PCA
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

explained = pca.explained_variance_ratio_ * 100
print(f"PC1 explains {explained[0]:.1f}%")
print(f"PC2 explains {explained[1]:.1f}%")
print(f"Total        {sum(explained):.1f}%")

colors = ['#7F77DD', '#1D9E75', '#D85A30', '#EF9F27', '#D4537E', '#378ADD']

plt.figure(figsize=(9, 6))
for c in range(BEST_K):
    mask = user_features['cluster'] == c
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1],
                label=f'Cluster {c}',
                color=colors[c], alpha=0.5, s=15)

plt.title(f'User clusters — PCA view ({sum(explained):.0f}% variance)')
plt.xlabel(f'PC1 ({explained[0]:.1f}%)')
plt.ylabel(f'PC2 ({explained[1]:.1f}%)')
plt.legend()
plt.tight_layout()
plt.savefig('../data/processed/plot_clusters_pca.png', dpi=120)
plt.show()
# Out:
# PC1 explains 24.8%
# PC2 explains 19.3%
# Total        44.1%

# %%
# Cell 5 — Visualise clusters in 2D using PCA
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

explained = pca.explained_variance_ratio_ * 100
print(f"PC1 explains {explained[0]:.1f}%")
print(f"PC2 explains {explained[1]:.1f}%")
print(f"Total        {sum(explained):.1f}%")

colors = ['#7F77DD', '#1D9E75', '#D85A30', '#EF9F27', '#D4537E', '#378ADD']

plt.figure(figsize=(9, 6))
for c in range(BEST_K):
    mask = user_features['cluster'] == c
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1],
                label=f'Cluster {c}',
                color=colors[c], alpha=0.5, s=15)

plt.title(f'User clusters — PCA view ({sum(explained):.0f}% variance)')
plt.xlabel(f'PC1 ({explained[0]:.1f}%)')
plt.ylabel(f'PC2 ({explained[1]:.1f}%)')
plt.legend()
plt.tight_layout()
plt.savefig('../data/processed/plot_clusters_pca.png', dpi=120)
plt.show()
# Out:
# PC1 explains 24.8%
# PC2 explains 19.3%
# Total        44.1%

# %%
# Cell 6 — Profile each cluster
profile = user_features.groupby('cluster')[cluster_cols].mean().T
print("=== Cluster Profiles (mean values) ===")
print(profile.round(2))
# Out:
# === Cluster Profiles (mean values) ===
# cluster                     0        1        2        3
# total_plays             15.44    15.09    16.72    92.51
# unique_tracks            6.18     5.04     6.42    35.86
# unique_artists           4.04     3.55     5.10    21.51
# repeat_rate              2.77     3.39     2.79     3.17
# artist_loyalty           0.60     0.64     0.50     0.25
# genre_diversity          1.64     1.39     1.91     4.26
# avg_danceability         0.50     0.46     0.61     0.53
# avg_energy               0.49     0.80     0.70     0.68
# avg_valence              0.38     0.41     0.57     0.46
# avg_acousticness         0.45     0.09     0.18     0.22
# avg_instrumentalness     0.23     0.13     0.09     0.17
# avg_tempo              116.57   133.83   119.65   123.44
# avg_loudness           -10.90    -6.21    -7.13    -7.85
# avg_track_year        2003.88  2005.13  2005.31  2004.83

# %%
# Cell 7 — Heatmap of cluster profiles
profile_norm = (profile - profile.min()) / (profile.max() - profile.min())

plt.figure(figsize=(9, 8))
sns.heatmap(profile_norm, annot=True, fmt='.2f',
            cmap='RdYlGn', linewidths=0.5, cbar=False)
plt.title('Cluster feature heatmap (normalised 0–1)')
plt.tight_layout()
plt.savefig('../data/processed/plot_cluster_heatmap.png', dpi=120)
plt.show()

# %%
# Cell 8 — Name your clusters (fill in after reviewing Cell 6 output)
# Examples based on typical patterns — update after seeing your data
cluster_names = {
    0: 'Energetic Pop Fans',
    1: 'Chill Acoustic Listeners',
    2: 'Loyal Superfans',
    3: 'Casual Explorers',
}

user_features['segment'] = user_features['cluster'].map(cluster_names)

print("Segment distribution:")
print(user_features['segment'].value_counts())

# Save
user_features.to_csv('../data/processed/user_features.csv', index=False)
print("\nSaved with cluster labels ✓")
# Out:
# Segment distribution:
# segment
# Loyal Superfans             408553
# Chill Acoustic Listeners    248907
# Energetic Pop Fans          171422
# Casual Explorers            133155
# Name: count, dtype: int64
#
# Saved with cluster labels ✓
